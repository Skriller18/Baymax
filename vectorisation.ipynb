# %%
import gensim
from gensim.models import Word2Vec
from transformers import GPT2LMHeadModel, GPT2Tokenizer
import torch
import numpy as np

# Step 1: Load and preprocess your input text file
def load_and_preprocess(file_path):
    with open(file_path, 'r', encoding='utf-8') as file:
        text = file.read()
    sentences = [sentence.split() for sentence in text.split('.')]
    return sentences

# Step 2: Train Word2Vec model
def train_word2vec(sentences):
    model = Word2Vec(sentences, vector_size=100, window=5, min_count=1, workers=4)
    return model

# Step 3: Fine-tune GPT-2 model
def fine_tune_gpt2(sentences, word2vec_model):
    tokenizer = GPT2Tokenizer.from_pretrained('gpt2')
    model = GPT2LMHeadModel.from_pretrained('gpt2')

    # Prepare input data
    input_ids = []
    for sentence in sentences:
        tokens = tokenizer.encode(' '.join(sentence), add_special_tokens=True)
        input_ids.append(torch.tensor(tokens))

    # Fine-tune the model
    model.train()
    optimizer = torch.optim.Adam(model.parameters(), lr=5e-5)

    for epoch in range(3):  # Adjust number of epochs as needed
        for batch in input_ids:
            outputs = model(batch, labels=batch)
            loss = outputs.loss
            loss.backward()
            optimizer.step()
            optimizer.zero_grad()

    return model, tokenizer

# Step 4: Perform question-answering
def question_answering(question, context, model, tokenizer, word2vec_model):
    # Combine question and context
    input_text = f"Question: {question}\nContext: {context}\nAnswer:"
    input_ids = tokenizer.encode(input_text, return_tensors='pt')

    # Generate answer
    output = model.generate(input_ids, max_length=100, num_return_sequences=1, no_repeat_ngram_size=2)
    answer = tokenizer.decode(output[0], skip_special_tokens=True)

    return answer

# Main execution
if __name__ == "__main__":
    file_path = "context.txt"
    sentences = load_and_preprocess(file_path)
    
    word2vec_model = train_word2vec(sentences)
    gpt2_model, tokenizer = fine_tune_gpt2(sentences, word2vec_model)

    # Example usage
    context = "A hospital receptionist"
    question = "I need to cancel my appointment for Wednesday."
    
    answer = question_answering(question, context, gpt2_model, tokenizer, word2vec_model)
    print(f"Question: {question}")
    print(f"Answer: {answer}")
# Out:
# c:\Users\user1\.conda\envs\env\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Question: I need to cancel my appointment for Wednesday.
# Answer: Question: I need to cancel my appointment for Wednesday.
# Context: A hospital receptionist
# Answer: Monday works Wednesday Friday: Bye Monday?: That's fine Monday, Wednesday works fine Wednesday Wednesday: Okay Monday is fine?: Wednesday is Monday: Wednesday's work?: Okay, Monday's Monday will be fine: Friday works Monday Monday Wednesday Monday Friday Monday Tuesday Wednesday Thursday Friday Friday Saturday: works Friday and Wednesday will work Friday?: You're welcome?: Thanks for waiting for me!: Okay thanks for letting me

# %%
import gensim
from gensim.models import Word2Vec
import nltk
from nltk.tokenize import word_tokenize, sent_tokenize
import numpy as np

# Download necessary NLTK data
nltk.download('punkt')

def preprocess_text(file_path):
    with open(file_path, 'r', encoding='utf-8') as file:
        text = file.read()
    # Tokenize the text into sentences
    sentences = sent_tokenize(text)
    # Tokenize each sentence into words
    tokenized_sentences = [word_tokenize(sentence.lower()) for sentence in sentences]
    return tokenized_sentences

def train_word2vec(sentences, vector_size=100, window=5, min_count=1, workers=4):
    model = Word2Vec(sentences, vector_size=vector_size, window=window, min_count=min_count, workers=workers)
    return model

def explore_word2vec(model, word):
    try:
        # Get the vector for a word
        vector = model.wv[word]
        print(f"Vector for '{word}': {vector[:5]}... (showing first 5 dimensions)")
        
        # Find similar words
        similar_words = model.wv.most_similar(word, topn=5)
        print(f"\nTop 5 similar words to '{word}':")
        for similar_word, score in similar_words:
            print(f"{similar_word}: {score:.4f}")
        print("\n" + "-"*50 + "\n")
    
    except KeyError:
        print(f"'{word}' not in vocabulary")

# Main execution
if __name__ == "__main__":
    file_path = "context.txt" 
    # Preprocess the text
    sentences = preprocess_text(file_path)
    
    # Train the Word2Vec model
    model = train_word2vec(sentences)
    
    # Save the model
    model.save("word2vec_model.bin")
    print("Word2Vec model trained and saved.")
    
    # Explore the model for all words in the vocabulary
    vocabulary = list(model.wv.key_to_index.keys())
    print(f"\nExploring all {len(vocabulary)} words in the vocabulary:\n")
    
    for word in vocabulary:
        explore_word2vec(model, word)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\user1\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# Word2Vec model trained and saved.
#
# Exploring all 234 words in the vocabulary:
#
# Vector for '.': [-0.00067933  0.00078535  0.00518064  0.00898539 -0.00913443]... (showing first 5 dimensions)
#
# Top 5 similar words to '.':
# good: 0.3175
# three: 0.2879
# such: 0.2826
# communication: 0.2538
# edgar: 0.2383
#
# --------------------------------------------------
#
# Vector for 'you': [-0.00865384  0.00415911  0.00535747  0.00574585  0.00770615]... (showing first 5 dimensions)
#
# Top 5 similar words to 'you':
# asking: 0.2274
# pm: 0.2169
# phone: 0.1995
# such: 0.1979
# communication: 0.1968
#
# --------------------------------------------------
#
# Vector for '?': [ 4.8910446e-05  3.2708663e-03 -6.8035577e-03 -1.4380853e-03
#   7.7291098e-03]... (showing first 5 dimensions)
#
# Top 5 similar words to '?':
# my: 0.3872
# &: 0.2187
# name: 0.2187
# dr.: 0.2093
# desk: 0.2061
#
# --------------------------------------------------
#
# Vector for 'a': [-8.3736507e-03  9.6544959e-03 -9.2086309e-05 -2.0035380e-03
#   4.6665696e-03]... (showing first 5 dimensions)
#
# Top 5 similar words to 'a':
# when: 0.2994
# street: 0.2745
# inquiries: 0.2586
# which: 0.2402
# letting: 0.2278
#
# --------------------------------------------------
#
# Vector for 'is': [-0.0072382   0.00159468 -0.00712045 -0.00228333  0.00386008]... (showing first 5 dimensions)
#
# Top 5 similar words to 'is':
# who: 0.2755
# for: 0.2613
# changed: 0.2435
# desk: 0.2149
# prescription: 0.2148
#
# --------------------------------------------------
#
# Vector for ''s': [-0.00878065  0.00256786 -0.00069644 -0.00936801 -0.00934269]... (showing first 5 dimensions)
#
# Top 5 similar words to ''s':
# then: 0.3246
# help: 0.3112
# my: 0.3029
# hold: 0.2482
# handles: 0.2164
#
# --------------------------------------------------
#
# Vector for ';': [ 0.00796579 -0.0040578  -0.00092636  0.00101951 -0.00010467]... (showing first 5 dimensions)
#
# Top 5 similar words to ';':
# let: 0.3653
# office: 0.3120
# ways: 0.2920
# appointment: 0.2598
# contact: 0.2549
#
# --------------------------------------------------
#
# Vector for 'nbsp': [ 0.00792666 -0.00405144  0.00901877  0.00833704 -0.00432061]... (showing first 5 dimensions)
#
# Top 5 similar words to 'nbsp':
# patient: 0.3224
# which: 0.2509
# 3: 0.2448
# ways: 0.2293
# health: 0.2260
#
# --------------------------------------------------
#
# Vector for '&': [-0.00973077  0.00943413  0.00431239  0.00926496  0.0067952 ]... (showing first 5 dimensions)
#
# Top 5 similar words to '&':
# phone: 0.2955
# dr.: 0.2451
# ?: 0.2187
# welcome: 0.2156
# busy: 0.2088
#
# --------------------------------------------------
#
# Vector for ',': [-0.00526495 -0.00649584 -0.00772097  0.00831216 -0.00191247]... (showing first 5 dimensions)
#
# Top 5 similar words to ',':
# listen: 0.3145
# communication: 0.2576
# works: 0.2509
# cancel: 0.2338
# .: 0.2237
#
# --------------------------------------------------
#
# Vector for 'i': [ 0.00705684 -0.00135631  0.00805177 -0.00941784 -0.00797597]... (showing first 5 dimensions)
#
# Top 5 similar words to 'i':
# monday: 0.2721
# en: 0.2424
# inquiries: 0.2195
# cancelling: 0.2186
# yes: 0.2156
#
# --------------------------------------------------
#
# Vector for 'can': [0.00974528 0.00849966 0.0013776  0.00508789 0.00155954]... (showing first 5 dimensions)
#
# Top 5 similar words to 'can':
# my: 0.3368
# 10: 0.3193
# good: 0.2059
# time: 0.2013
# afternoon: 0.2007
#
# --------------------------------------------------
#
# Vector for 'how': [-0.00197702 -0.00508493  0.00946967 -0.0093255   0.00454253]... (showing first 5 dimensions)
#
# Top 5 similar words to 'how':
# let: 0.2567
# see: 0.2457
# three: 0.2192
# receptionists: 0.2017
# marcelli: 0.1861
#
# --------------------------------------------------
#
# Vector for 'for': [-0.00961668  0.00989308 -0.00767967 -0.00266848 -0.00477224]... (showing first 5 dimensions)
#
# Top 5 similar words to 'for':
# is: 0.2613
# 3: 0.2305
# help: 0.2130
# communicates: 0.1980
# card: 0.1845
#
# --------------------------------------------------
#
# Vector for 'and': [ 0.00764052  0.00940056  0.00119168 -0.0082943   0.00846903]... (showing first 5 dimensions)
#
# Top 5 similar words to 'and':
# 're: 0.2716
# will: 0.2565
# calls: 0.2362
# three: 0.2172
# waiting: 0.1990
#
# --------------------------------------------------
#
# Vector for 'your': [-0.00721786  0.00441418  0.00221248  0.0074327  -0.00481543]... (showing first 5 dimensions)
#
# Top 5 similar words to 'your':
# duties: 0.2149
# should: 0.2129
# today: 0.2118
# wanted: 0.2101
# what: 0.1977
#
# --------------------------------------------------
#
# Vector for 'edgar': [ 0.0012754  -0.00958881  0.00465684 -0.00053123  0.00637535]... (showing first 5 dimensions)
#
# Top 5 similar words to 'edgar':
# about: 0.2666
# bye-bye: 0.2436
# .: 0.2383
# speaking: 0.2360
# time: 0.2308
#
# --------------------------------------------------
#
# Vector for 'will': [ 0.00174412  0.00734645  0.00296409 -0.00693433  0.00780659]... (showing first 5 dimensions)
#
# Top 5 similar words to 'will':
# information: 0.2808
# and: 0.2565
# vocabulary: 0.2203
# numbers: 0.2179
# friday: 0.2164
#
# --------------------------------------------------
#
# Vector for 'in': [ 0.00967441 -0.00950003 -0.00645818  0.00286208  0.00652568]... (showing first 5 dimensions)
#
# Top 5 similar words to 'in':
# remember: 0.2427
# works: 0.2184
# afternoon: 0.2097
# check: 0.2037
# now: 0.1970
#
# --------------------------------------------------
#
# Vector for 'patient': [ 0.00552888  0.00580781  0.0019326   0.00575659 -0.00891582]... (showing first 5 dimensions)
#
# Top 5 similar words to 'patient':
# nbsp: 0.3224
# know: 0.2490
# office: 0.1874
# webvtt: 0.1686
# and: 0.1636
#
# --------------------------------------------------
#
# Vector for 'to': [ 0.00245877  0.00127751 -0.00252866  0.00931405  0.00293737]... (showing first 5 dimensions)
#
# Top 5 similar words to 'to':
# my: 0.2823
# it: 0.2559
# today: 0.2458
# 145: 0.2123
# okay: 0.1995
#
# --------------------------------------------------
#
# Vector for 'the': [ 0.0011965   0.00698495  0.01009353  0.00912271 -0.00793163]... (showing first 5 dimensions)
#
# Top 5 similar words to 'the':
# 00: 0.2622
# contact: 0.2422
# receptionist: 0.2164
# look: 0.2027
# webvtt: 0.2002
#
# --------------------------------------------------
#
# Vector for 'what': [-0.00028052  0.0044451   0.00214353  0.0099462   0.00068355]... (showing first 5 dimensions)
#
# Top 5 similar words to 'what':
# numbers: 0.2713
# three: 0.2359
# no: 0.2286
# 145: 0.2138
# who: 0.2106
#
# --------------------------------------------------
#
# Vector for 'at': [-0.00259987 -0.00560212  0.00755973 -0.0072706  -0.00887699]... (showing first 5 dimensions)
#
# Top 5 similar words to 'at':
# street: 0.2607
# helpful: 0.2426
# as: 0.2217
# health: 0.1851
# more: 0.1794
#
# --------------------------------------------------
#
# Vector for 'that': [-0.00502397 -0.00105449  0.00335193 -0.0064476  -0.00959811]... (showing first 5 dimensions)
#
# Top 5 similar words to 'that':
# report: 0.2546
# has: 0.2461
# pm: 0.2160
# need: 0.1994
# good: 0.1959
#
# --------------------------------------------------
#
# Vector for 'receptionist': [ 0.00957117  0.00763713  0.00138204 -0.00338484 -0.00040841]... (showing first 5 dimensions)
#
# Top 5 similar words to 'receptionist':
# one: 0.2589
# has: 0.2563
# toronto: 0.2198
# the: 0.2164
# melissa: 0.2134
#
# --------------------------------------------------
#
# Vector for '!': [-0.00703529 -0.00225635 -0.00806296  0.00755371  0.00614117]... (showing first 5 dimensions)
#
# Top 5 similar words to '!':
# changed: 0.2818
# inquiries: 0.2405
# 1: 0.2286
# this: 0.2136
# is: 0.2088
#
# --------------------------------------------------
#
# Vector for 'phone': [ 0.00204737  0.00602076 -0.00200313  0.00317568  0.00854247]... (showing first 5 dimensions)
#
# Top 5 similar words to 'phone':
# &: 0.2955
# bye: 0.2669
# as: 0.2626
# waiting: 0.2569
# 9: 0.2424
#
# --------------------------------------------------
#
# Vector for 'office': [ 0.00828816 -0.00024825 -0.00938125  0.0048205  -0.00596264]... (showing first 5 dimensions)
#
# Top 5 similar words to 'office':
# ;: 0.3120
# communication: 0.2325
# .: 0.2079
# dr.: 0.1955
# very: 0.1884
#
# --------------------------------------------------
#
# Vector for 'dr': [-0.00436783 -0.00895875 -0.00173019 -0.00379142  0.0091616 ]... (showing first 5 dimensions)
#
# Top 5 similar words to 'dr':
# remember: 0.3115
# who: 0.2535
# calls: 0.2138
# ?: 0.1883
# very: 0.1864
#
# --------------------------------------------------
#
# Vector for 'okay': [ 0.00019516  0.00225829  0.0010787   0.00756405 -0.00440504]... (showing first 5 dimensions)
#
# Top 5 similar words to 'okay':
# report: 0.2344
# canceled: 0.2006
# to: 0.1995
# can: 0.1921
# over: 0.1888
#
# --------------------------------------------------
#
# Vector for 'please': [-0.00221175 -0.00956667  0.00932959  0.00208159 -0.0011025 ]... (showing first 5 dimensions)
#
# Top 5 similar words to 'please':
# just: 0.2269
# 2: 0.2239
# again: 0.2028
# polite: 0.1896
# been: 0.1863
#
# --------------------------------------------------
#
# Vector for 'see': [ 0.00634442 -0.0086038  -0.00729628 -0.0016323   0.00181876]... (showing first 5 dimensions)
#
# Top 5 similar words to 'see':
# between: 0.2478
# how: 0.2457
# have: 0.2344
# 10: 0.2322
# remember: 0.2235
#
# --------------------------------------------------
#
# Vector for 'say': [ 0.00476842 -0.00338494 -0.0041101   0.00120307 -0.00405193]... (showing first 5 dimensions)
#
# Top 5 similar words to 'say':
# toronto: 0.3162
# p.m: 0.3160
# an: 0.2905
# set: 0.2286
# skills: 0.2055
#
# --------------------------------------------------
#
# Vector for 'with': [-0.00155332 -0.00374727 -0.00430125 -0.00465414 -0.00551208]... (showing first 5 dimensions)
#
# Top 5 similar words to 'with':
# yonge: 0.2799
# good: 0.2348
# learn: 0.2223
# monday: 0.2109
# remember: 0.2062
#
# --------------------------------------------------
#
# Vector for 'some': [ 0.0078432  -0.00620304  0.00594664 -0.00025285 -0.00903316]... (showing first 5 dimensions)
#
# Top 5 similar words to 'some':
# as: 0.2609
# more: 0.2557
# again: 0.2416
# pharmacies: 0.2236
# wednesday: 0.2202
#
# --------------------------------------------------
#
# Vector for 'thanks': [ 0.00530875  0.01003595 -0.00704869 -0.00053549 -0.0049836 ]... (showing first 5 dimensions)
#
# Top 5 similar words to 'thanks':
# need: 0.2135
# rescheduling: 0.2123
# lesson: 0.2116
# en: 0.1918
# include: 0.1801
#
# --------------------------------------------------
#
# Vector for 'let': [ 0.00214518 -0.00740066  0.00569288 -0.00499525 -0.00321666]... (showing first 5 dimensions)
#
# Top 5 similar words to 'let':
# ;: 0.3653
# again: 0.3173
# am: 0.2715
# ways: 0.2684
# how: 0.2567
#
# --------------------------------------------------
#
# Vector for 'work': [-0.00787374 -0.00640003 -0.00313031  0.00660161 -0.00072583]... (showing first 5 dimensions)
#
# Top 5 similar words to 'work':
# include: 0.2336
# great: 0.2127
# patients: 0.2126
# 145: 0.2082
# is: 0.1967
#
# --------------------------------------------------
#
# Vector for 'doctor': [-0.00176963  0.0065993  -0.00925153 -0.00914248 -0.00517324]... (showing first 5 dimensions)
#
# Top 5 similar words to 'doctor':
# contact: 0.2593
# on: 0.1952
# this: 0.1943
# braxton: 0.1902
# sarah: 0.1525
#
# --------------------------------------------------
#
# Vector for 'as': [-0.00486498 -0.0040284  -0.00469448 -0.00974878 -0.00069475]... (showing first 5 dimensions)
#
# Top 5 similar words to 'as':
# we: 0.2686
# phone: 0.2626
# some: 0.2609
# again: 0.2325
# at: 0.2217
#
# --------------------------------------------------
#
# Vector for 'name': [-0.006549    0.0090174  -0.00154148 -0.00826844  0.00803634]... (showing first 5 dimensions)
#
# Top 5 similar words to 'name':
# if: 0.3964
# it: 0.2808
# yes: 0.2488
# good: 0.2190
# ?: 0.2187
#
# --------------------------------------------------
#
# Vector for 'hello': [ 0.00504963 -0.00416774 -0.00916986 -0.00906113  0.00631627]... (showing first 5 dimensions)
#
# Top 5 similar words to 'hello':
# then: 0.3078
# laboratories: 0.1897
# be: 0.1815
# duties: 0.1754
# fine: 0.1739
#
# --------------------------------------------------
#
# Vector for 'monday': [-0.00263013 -0.00783504 -0.00826429 -0.00757913  0.00356693]... (showing first 5 dimensions)
#
# Top 5 similar words to 'monday':
# i: 0.2721
# communication: 0.2246
# commonly: 0.2220
# fine: 0.2163
# with: 0.2109
#
# --------------------------------------------------
#
# Vector for 'am': [-0.00826491  0.00033839  0.00604244  0.00952785 -0.00282285]... (showing first 5 dimensions)
#
# Top 5 similar words to 'am':
# look: 0.3452
# let: 0.2715
# learn: 0.2284
# ,: 0.2171
# soon: 0.2164
#
# --------------------------------------------------
#
# Vector for 'wednesday': [ 0.00796201  0.00803397 -0.00540242 -0.00802186  0.00818747]... (showing first 5 dimensions)
#
# Top 5 similar words to 'wednesday':
# repeat: 0.2677
# moment: 0.2366
# inquiries: 0.2337
# some: 0.2202
# more: 0.2009
#
# --------------------------------------------------
#
# Vector for 'bye': [-0.00618686  0.00471813 -0.00909137  0.00510288  0.00639801]... (showing first 5 dimensions)
#
# Top 5 similar words to 'bye':
# phone: 0.2669
# day: 0.2325
# asking: 0.2290
# been: 0.2166
# it: 0.2105
#
# --------------------------------------------------
#
# Vector for 'appointment': [-0.00281501  0.00029276  0.002025   -0.00933544  0.00493704]... (showing first 5 dimensions)
#
# Top 5 similar words to 'appointment':
# time: 0.2772
# ;: 0.2598
# let: 0.2377
# greeting: 0.2191
# then: 0.2068
#
# --------------------------------------------------
#
# Vector for 'moment': [ 0.00060692  0.00664174  0.00592377 -0.00017476  0.00242609]... (showing first 5 dimensions)
#
# Top 5 similar words to 'moment':
# all: 0.2449
# wednesday: 0.2366
# melissa: 0.2027
# great: 0.2024
# call: 0.1820
#
# --------------------------------------------------
#
# Vector for 'number': [-0.00122781 -0.00215315 -0.00185911 -0.00115381 -0.00645   ]... (showing first 5 dimensions)
#
# Top 5 similar words to 'number':
# address: 0.2518
# ways: 0.2219
# information: 0.2133
# language: 0.2126
# contact: 0.2053
#
# --------------------------------------------------
#
# Vector for 'important': [ 0.00458468 -0.00872774 -0.00919676  0.00103162 -0.00848803]... (showing first 5 dimensions)
#
# Top 5 similar words to 'important':
# such: 0.2610
# braxton: 0.2599
# yonge: 0.2464
# address: 0.2221
# pm: 0.2136
#
# --------------------------------------------------
#
# Vector for '10': [ 0.00993793  0.00251009  0.0051635  -0.0056879   0.00444732]... (showing first 5 dimensions)
#
# Top 5 similar words to '10':
# can: 0.3193
# on: 0.2397
# see: 0.2322
# remember: 0.2120
# you: 0.1947
#
# --------------------------------------------------
#
# Vector for 'dr.': [ 6.9842236e-03  2.4359302e-05 -7.9656607e-03  8.8721998e-03
#  -8.4373578e-03]... (showing first 5 dimensions)
#
# Top 5 similar words to 'dr.':
# marceli: 0.2846
# communicates: 0.2612
# remember: 0.2468
# &: 0.2451
# 1: 0.2153
#
# --------------------------------------------------
#
# Vector for 'works': [-0.00339818 -0.00675509  0.00656346  0.0093593   0.00824994]... (showing first 5 dimensions)
#
# Top 5 similar words to 'works':
# found: 0.2744
# duties: 0.2667
# new: 0.2585
# ,: 0.2509
# pm: 0.2488
#
# --------------------------------------------------
#
# Vector for 'speaking': [-0.00788827 -0.00829229  0.0011736  -0.00074475 -0.00946599]... (showing first 5 dimensions)
#
# Top 5 similar words to 'speaking':
# conversations: 0.2864
# common: 0.2863
# greeting: 0.2439
# edgar: 0.2360
# setting: 0.2135
#
# --------------------------------------------------
#
# Vector for 'are': [-0.00240408  0.00766709  0.0020222   0.00293756 -0.00121791]... (showing first 5 dimensions)
#
# Top 5 similar words to 'are':
# braxton: 0.2605
# melissa: 0.2440
# afternoon: 0.2205
# desk: 0.2079
# reports: 0.2028
#
# --------------------------------------------------
#
# Vector for 'hi': [ 0.00993131  0.00063406 -0.00513121 -0.00361791  0.0012817 ]... (showing first 5 dimensions)
#
# Top 5 similar words to 'hi':
# inquiries: 0.2321
# polite: 0.2109
# wanted: 0.2098
# receptionist: 0.2058
# pharmacy: 0.1935
#
# --------------------------------------------------
#
# Vector for 'answering': [-0.00658135  0.00768095  0.00625258 -0.00490215 -0.00167138]... (showing first 5 dimensions)
#
# Top 5 similar words to 'answering':
# questions: 0.3064
# commonly: 0.2501
# my: 0.2347
# bye-bye: 0.2221
# helpful: 0.2184
#
# --------------------------------------------------
#
# Vector for 'waiting': [ 0.00112742  0.00630625 -0.00656276  0.00656039  0.00986401]... (showing first 5 dimensions)
#
# Top 5 similar words to 'waiting':
# phone: 0.2569
# seat: 0.2543
# numbers: 0.2390
# new: 0.2285
# know: 0.2199
#
# --------------------------------------------------
#
# Vector for 'over': [-0.00095209 -0.00502584  0.0092387   0.00337368  0.00435243]... (showing first 5 dimensions)
#
# Top 5 similar words to 'over':
# my: 0.2703
# toronto: 0.2618
# such: 0.2248
# nbsp: 0.2135
# conversation: 0.2046
#
# --------------------------------------------------
#
# Vector for 'all': [ 0.00258739 -0.00752222  0.00567621  0.00759845 -0.0025163 ]... (showing first 5 dimensions)
#
# Top 5 similar words to 'all':
# between: 0.2924
# 'll: 0.2894
# moment: 0.2449
# morning: 0.2171
# like: 0.2116
#
# --------------------------------------------------
#
# Vector for 'address': [ 0.00977182  0.00436214 -0.00206776 -0.0049732  -0.00970297]... (showing first 5 dimensions)
#
# Top 5 similar words to 'address':
# number: 0.2518
# important: 0.2221
# 's: 0.2049
# handles: 0.1965
# bye-bye: 0.1951
#
# --------------------------------------------------
#
# Vector for ''re': [ 0.00427532  0.00054161 -0.0008734  -0.00322242  0.00501571]... (showing first 5 dimensions)
#
# Top 5 similar words to ''re':
# and: 0.2716
# us: 0.2430
# possible: 0.2332
# next: 0.2306
# help: 0.2252
#
# --------------------------------------------------
#
# Vector for 'on': [ 0.00201415  0.00843049 -0.00824372 -0.00873063 -0.00048789]... (showing first 5 dimensions)
#
# Top 5 similar words to 'on':
# doctors: 0.3525
# us: 0.3347
# one: 0.2485
# 10: 0.2397
# more: 0.2147
#
# --------------------------------------------------
#
# Vector for 'now': [-0.00017751 -0.0098455  -0.00756009  0.00860186  0.00191947]... (showing first 5 dimensions)
#
# Top 5 similar words to 'now':
# desk: 0.2780
# wait: 0.2531
# 'll: 0.2145
# know: 0.2053
# nbsp: 0.2009
#
# --------------------------------------------------
#
# Vector for 'look': [-0.00813423 -0.00073454  0.00648021  0.00870315 -0.004972  ]... (showing first 5 dimensions)
#
# Top 5 similar words to 'look':
# am: 0.3452
# .: 0.2267
# hope: 0.2229
# changed: 0.2205
# contact: 0.2149
#
# --------------------------------------------------
#
# Vector for 'have': [-0.00848949  0.00658876 -0.00578351 -0.00173428  0.00100618]... (showing first 5 dimensions)
#
# Top 5 similar words to 'have':
# wait: 0.3586
# see: 0.2344
# information: 0.2276
# soon: 0.2205
# helpful: 0.2114
#
# --------------------------------------------------
#
# Vector for 'be': [ 0.00857427 -0.00573875 -0.00757903 -0.00141378  0.00302606]... (showing first 5 dimensions)
#
# Top 5 similar words to 'be':
# card: 0.3427
# reports: 0.2836
# duties: 0.2743
# ): 0.2131
# after: 0.2099
#
# --------------------------------------------------
#
# Vector for 'my': [-0.00235915  0.00228093  0.00776641 -0.00566782  0.00392991]... (showing first 5 dimensions)
#
# Top 5 similar words to 'my':
# ?: 0.3872
# can: 0.3368
# 's: 0.3029
# to: 0.2823
# over: 0.2703
#
# --------------------------------------------------
#
# Vector for '3': [ 0.0030562  -0.00153042 -0.00118555 -0.00585463 -0.00576434]... (showing first 5 dimensions)
#
# Top 5 similar words to '3':
# skills: 0.2888
# messages: 0.2786
# nbsp: 0.2448
# for: 0.2305
# like: 0.2182
#
# --------------------------------------------------
#
# Vector for 'day': [0.00231    0.00446122 0.00196344 0.00813155 0.00892515]... (showing first 5 dimensions)
#
# Top 5 similar words to 'day':
# inquire: 0.2610
# bye: 0.2325
# call: 0.2295
# 289-548-9280: 0.2114
# us: 0.2095
#
# --------------------------------------------------
#
# Vector for 'next': [ 0.00414711  0.00261915 -0.00032621 -0.00055597  0.00271253]... (showing first 5 dimensions)
#
# Top 5 similar words to 'next':
# pharmacies: 0.2675
# us: 0.2486
# 're: 0.2306
# welcome: 0.2215
# been: 0.2139
#
# --------------------------------------------------
#
# Vector for 'good': [-0.00754333  0.00691751 -0.00332501 -0.00089383  0.00540179]... (showing first 5 dimensions)
#
# Top 5 similar words to 'good':
# .: 0.3175
# include: 0.2964
# would: 0.2798
# yes: 0.2526
# with: 0.2348
#
# --------------------------------------------------
#
# Vector for 'help': [-0.00063567  0.00148817 -0.00115799 -0.00402573  0.00090656]... (showing first 5 dimensions)
#
# Top 5 similar words to 'help':
# 's: 0.3112
# of: 0.2876
# my: 0.2519
# bye-bye: 0.2471
# melissa: 0.2387
#
# --------------------------------------------------
#
# Vector for 'thank': [ 0.00307883 -0.00968154  0.00323723 -0.00447925  0.00971544]... (showing first 5 dimensions)
#
# Top 5 similar words to 'thank':
# pharmacies: 0.3003
# 145: 0.2299
# more: 0.2200
# 'll: 0.2128
# helpful: 0.1855
#
# --------------------------------------------------
#
# Vector for 'or': [-0.00719601  0.00647543 -0.00193844 -0.00476541  0.00502045]... (showing first 5 dimensions)
#
# Top 5 similar words to 'or':
# webvtt: 0.1911
# am: 0.1838
# asking: 0.1792
# that: 0.1677
# someone: 0.1675
#
# --------------------------------------------------
#
# Vector for 'blood': [-0.00705668  0.00933035  0.00644023 -0.00410952 -0.00294313]... (showing first 5 dimensions)
#
# Top 5 similar words to 'blood':
# language: 0.3136
# great: 0.2986
# seat: 0.2376
# me: 0.2079
# works: 0.1908
#
# --------------------------------------------------
#
# Vector for 'one': [ 0.00094353  0.00874506 -0.00399551  0.00302172  0.00327807]... (showing first 5 dimensions)
#
# Top 5 similar words to 'one':
# long: 0.2595
# receptionist: 0.2589
# on: 0.2485
# 'm: 0.2131
# us: 0.2010
#
# --------------------------------------------------
#
# Vector for 'hold': [ 0.00542702  0.00698488  0.00614892 -0.00950999  0.00972763]... (showing first 5 dimensions)
#
# Top 5 similar words to 'hold':
# learn: 0.3163
# 's: 0.2482
# person: 0.2361
# me: 0.2347
# let: 0.2235
#
# --------------------------------------------------
#
# Vector for 'morning': [-0.0022473   0.00760949 -0.00308888  0.00353567  0.00019221]... (showing first 5 dimensions)
#
# Top 5 similar words to 'morning':
# of: 0.2977
# card: 0.2449
# conversation: 0.2417
# 00: 0.2279
# all: 0.2171
#
# --------------------------------------------------
#
# Vector for 'great': [0.00595633 0.00386497 0.00179232 0.00065064 0.00883671]... (showing first 5 dimensions)
#
# Top 5 similar words to 'great':
# blood: 0.2986
# seat: 0.2678
# repeat: 0.2332
# work: 0.2127
# moment: 0.2024
#
# --------------------------------------------------
#
# Vector for 'would': [-0.00991775 -0.00022378 -0.00465396 -0.00423624 -0.00177835]... (showing first 5 dimensions)
#
# Top 5 similar words to 'would':
# good: 0.2798
# then: 0.2584
# yonge: 0.2475
# managing: 0.2017
# answering: 0.1988
#
# --------------------------------------------------
#
# Vector for 'include': [ 0.00498506 -0.00349241  0.00353134  0.00076737  0.00904549]... (showing first 5 dimensions)
#
# Top 5 similar words to 'include':
# good: 0.2964
# yes: 0.2572
# sure: 0.2339
# work: 0.2336
# time: 0.2197
#
# --------------------------------------------------
#
# Vector for 'it': [-0.00911947  0.00565819  0.00380852 -0.00601032  0.00615513]... (showing first 5 dimensions)
#
# Top 5 similar words to 'it':
# name: 0.2808
# to: 0.2559
# desk: 0.2442
# ): 0.2131
# phone: 0.2122
#
# --------------------------------------------------
#
# Vector for 'who': [0.00412768 0.00036839 0.00486274 0.00296062 0.0014431 ]... (showing first 5 dimensions)
#
# Top 5 similar words to 'who':
# is: 0.2755
# has: 0.2580
# dr: 0.2535
# what: 0.2106
# desk: 0.2040
#
# --------------------------------------------------
#
# Vector for 'melissa': [0.00933647 0.00749717 0.00695656 0.00607573 0.00502468]... (showing first 5 dimensions)
#
# Top 5 similar words to 'melissa':
# are: 0.2440
# help: 0.2387
# questions: 0.2321
# has: 0.2187
# receptionist: 0.2134
#
# --------------------------------------------------
#
# Vector for 'fine': [ 0.00728652 -0.00062975  0.0057434  -0.00911534  0.00060857]... (showing first 5 dimensions)
#
# Top 5 similar words to 'fine':
# monday: 0.2163
# 219: 0.1914
# and: 0.1899
# number: 0.1893
# 'm: 0.1832
#
# --------------------------------------------------
#
# Vector for 'health': [-0.00403204  0.002783    0.00164449 -0.00927108  0.00836984]... (showing first 5 dimensions)
#
# Top 5 similar words to 'health':
# asking: 0.2773
# nbsp: 0.2260
# has: 0.2203
# it: 0.2087
# about: 0.1969
#
# --------------------------------------------------
#
# Vector for 'time': [-4.5431508e-03  4.4518325e-05  4.4052289e-03 -9.9122897e-03
#   3.8277721e-03]... (showing first 5 dimensions)
#
# Top 5 similar words to 'time':
# wait: 0.2888
# appointment: 0.2772
# edgar: 0.2308
# include: 0.2197
# me: 0.2176
#
# --------------------------------------------------
#
# Vector for 'welcome': [ 0.00329449  0.00915986  0.00677192 -0.01000999 -0.00153556]... (showing first 5 dimensions)
#
# Top 5 similar words to 'welcome':
# let: 0.2423
# next: 0.2215
# &: 0.2156
# card: 0.1949
# friday: 0.1796
#
# --------------------------------------------------
#
# Vector for 'card': [ 0.00625526 -0.00039321 -0.00413123 -0.0036648  -0.00594374]... (showing first 5 dimensions)
#
# Top 5 similar words to 'card':
# be: 0.3427
# morning: 0.2449
# friday: 0.2421
# back: 0.2167
# 3: 0.2132
#
# --------------------------------------------------
#
# Vector for 'today': [-0.0003168   0.00357159 -0.00662362  0.00743471 -0.00491207]... (showing first 5 dimensions)
#
# Top 5 similar words to 'today':
# commonly: 0.3294
# p.m: 0.2907
# ): 0.2726
# wonderful: 0.2594
# to: 0.2458
#
# --------------------------------------------------
#
# Vector for 'we': [-0.00201898 -0.00495152 -0.00849274 -0.00932796  0.00444969]... (showing first 5 dimensions)
#
# Top 5 similar words to 'we':
# as: 0.2686
# ways: 0.2553
# information: 0.2283
# commonly: 0.2212
# conversations: 0.1944
#
# --------------------------------------------------
#
# Vector for 'new': [-0.00297371  0.00511758 -0.00161659 -0.00915897 -0.0032377 ]... (showing first 5 dimensions)
#
# Top 5 similar words to 'new':
# works: 0.2585
# doctors: 0.2390
# duties: 0.2373
# p.m: 0.2313
# waiting: 0.2285
#
# --------------------------------------------------
#
# Vector for 'vocabulary': [ 0.00184602  0.00468525  0.00149398 -0.00533759  0.00983672]... (showing first 5 dimensions)
#
# Top 5 similar words to 'vocabulary':
# desk: 0.2858
# yonge: 0.2409
# inquiries: 0.2320
# will: 0.2203
# minute: 0.2131
#
# --------------------------------------------------
#
# Vector for 'has': [ 0.00375801  0.00169164 -0.00316702 -0.00727325  0.00253835]... (showing first 5 dimensions)
#
# Top 5 similar words to 'has':
# need: 0.4193
# taking: 0.2688
# who: 0.2580
# receptionist: 0.2563
# that: 0.2461
#
# --------------------------------------------------
#
# Vector for 'communication': [-0.00710247 -0.00019345  0.00378028  0.00418976  0.00243484]... (showing first 5 dimensions)
#
# Top 5 similar words to 'communication':
# pharmacy: 0.3124
# long: 0.2941
# ,: 0.2576
# .: 0.2538
# office: 0.2325
#
# --------------------------------------------------
#
# Vector for 'conversations': [-0.00417687 -0.00966588 -0.00706132 -0.00990792  0.00793991]... (showing first 5 dimensions)
#
# Top 5 similar words to 'conversations':
# doctors: 0.2965
# speaking: 0.2864
# laboratories: 0.2608
# sure: 0.2432
# greeting: 0.2322
#
# --------------------------------------------------
#
# Vector for '9': [-0.00626026 -0.00046103 -0.00948273  0.0078331  -0.00561605]... (showing first 5 dimensions)
#
# Top 5 similar words to '9':
# receptionists: 0.2613
# check: 0.2551
# phone: 0.2424
# when: 0.2097
# 145: 0.1963
#
# --------------------------------------------------
#
# Vector for 'an': [-0.00046611  0.00913625 -0.00312389  0.00624101 -0.00846202]... (showing first 5 dimensions)
#
# Top 5 similar words to 'an':
# say: 0.2905
# asking: 0.2390
# managing: 0.2330
# no: 0.2286
# ways: 0.2229
#
# --------------------------------------------------
#
# Vector for 'this': [ 0.00329051 -0.00894602  0.00465853  0.00471303 -0.00767968]... (showing first 5 dimensions)
#
# Top 5 similar words to 'this':
# toronto: 0.2657
# friday: 0.2296
# !: 0.2136
# after: 0.2057
# all: 0.1999
#
# --------------------------------------------------
#
# Vector for 'patients': [ 0.00596679 -0.00538227  0.00796834  0.00674921 -0.00691371]... (showing first 5 dimensions)
#
# Top 5 similar words to 'patients':
# 145: 0.2684
# webvtt: 0.2442
# work: 0.2126
# prescription: 0.2011
# learn: 0.1957
#
# --------------------------------------------------
#
# Vector for 'person': [-0.00059716  0.00421698  0.00313257  0.00665139  0.0098514 ]... (showing first 5 dimensions)
#
# Top 5 similar words to 'person':
# setting: 0.3692
# hold: 0.2361
# still: 0.2263
# are: 0.2015
# you: 0.1940
#
# --------------------------------------------------
#
# Vector for 'reports': [ 0.00617855 -0.00195186  0.00624578  0.00153021  0.00443501]... (showing first 5 dimensions)
#
# Top 5 similar words to 'reports':
# be: 0.2836
# after: 0.2794
# ): 0.2781
# laboratories: 0.2365
# en: 0.2179
#
# --------------------------------------------------
#
# Vector for 'wanted': [ 0.00429205  0.00706039  0.00095597 -0.00585569  0.00456516]... (showing first 5 dimensions)
#
# Top 5 similar words to 'wanted':
# three: 0.2968
# 1: 0.2647
# repeat: 0.2402
# your: 0.2101
# hi: 0.2098
#
# --------------------------------------------------
#
# Vector for 'someone': [ 0.00241967  0.00616064 -0.00961899 -0.00141857  0.00513097]... (showing first 5 dimensions)
#
# Top 5 similar words to 'someone':
# setting: 0.2728
# 1: 0.2597
# rescheduling: 0.2464
# let: 0.2365
# laboratories: 0.2287
#
# --------------------------------------------------
#
# Vector for 'friday': [-0.00160988  0.00242224  0.00547126 -0.0002388   0.00028445]... (showing first 5 dimensions)
#
# Top 5 similar words to 'friday':
# back: 0.2893
# card: 0.2421
# this: 0.2296
# will: 0.2164
# messages: 0.1965
#
# --------------------------------------------------
#
# Vector for 'calls': [ 0.00967672 -0.00089433 -0.00692978 -0.002014    0.00615581]... (showing first 5 dimensions)
#
# Top 5 similar words to 'calls':
# long: 0.2492
# and: 0.2362
# dr: 0.2138
# taking: 0.1885
# hello: 0.1667
#
# --------------------------------------------------
#
# Vector for 'liam': [ 0.00796214 -0.0067685   0.00031421  0.00313117 -0.0020951 ]... (showing first 5 dimensions)
#
# Top 5 similar words to 'liam':
# changed: 0.2605
# 289-548-9280: 0.2112
# cancel: 0.2093
# appointment: 0.1808
# melissa: 0.1770
#
# --------------------------------------------------
#
# Vector for 'soon': [-0.00250147 -0.00213814  0.00878367  0.00736213 -0.00265663]... (showing first 5 dimensions)
#
# Top 5 similar words to 'soon':
# like: 0.2479
# have: 0.2205
# am: 0.2164
# look: 0.2072
# hope: 0.2015
#
# --------------------------------------------------
#
# Vector for 'booking': [-0.00011773 -0.00845016 -0.00669122  0.001221   -0.00962999]... (showing first 5 dimensions)
#
# Top 5 similar words to 'booking':
# questions: 0.2409
# letting: 0.2276
# about: 0.2265
# conversations: 0.2142
# nurse: 0.2117
#
# --------------------------------------------------
#
# Vector for 'taking': [ 0.00901927  0.00011931 -0.00486329 -0.00745256  0.00344488]... (showing first 5 dimensions)
#
# Top 5 similar words to 'taking':
# numbers: 0.2701
# has: 0.2688
# waiting: 0.2116
# very: 0.2084
# calls: 0.1885
#
# --------------------------------------------------
#
# Vector for 'pharmacies': [ 5.7135937e-03 -7.9732183e-03  7.8549273e-03 -7.1347182e-05
#   8.8491263e-03]... (showing first 5 dimensions)
#
# Top 5 similar words to 'pharmacies':
# thank: 0.3003
# next: 0.2675
# three: 0.2479
# greeting: 0.2309
# some: 0.2236
#
# --------------------------------------------------
#
# Vector for 'appointments': [-0.00134997  0.00039471 -0.00385956  0.00558422 -0.00618092]... (showing first 5 dimensions)
#
# Top 5 similar words to 'appointments':
# first: 0.2297
# ways: 0.1921
# is: 0.1792
# still: 0.1775
# questions: 0.1750
#
# --------------------------------------------------
#
# Vector for 'rescheduling': [ 0.00968247  0.0067115  -0.00921156 -0.00711115 -0.0083911 ]... (showing first 5 dimensions)
#
# Top 5 similar words to 'rescheduling':
# common: 0.2836
# someone: 0.2464
# conversations: 0.2306
# let: 0.2229
# thanks: 0.2123
#
# --------------------------------------------------
#
# Vector for 'cancelling': [ 0.00085198 -0.00081672  0.00892538 -0.00468404 -0.00737739]... (showing first 5 dimensions)
#
# Top 5 similar words to 'cancelling':
# messages: 0.2503
# again: 0.2460
# i: 0.2186
# some: 0.2127
# marceli: 0.2026
#
# --------------------------------------------------
#
# Vector for 'duties': [ 0.00910474  0.00137725 -0.00443705  0.00646077  0.00558776]... (showing first 5 dimensions)
#
# Top 5 similar words to 'duties':
# be: 0.2743
# works: 0.2667
# pharmacy: 0.2484
# new: 0.2373
# communicates: 0.2199
#
# --------------------------------------------------
#
# Vector for 'wonderful': [-0.00719569 -0.00594646  0.00300635  0.00448136 -0.00837425]... (showing first 5 dimensions)
#
# Top 5 similar words to 'wonderful':
# nurse: 0.2658
# numbers: 0.2644
# today: 0.2594
# communication: 0.2310
# pharmacy: 0.2250
#
# --------------------------------------------------
#
# Vector for 'laboratories': [-0.00419489  0.00104397 -0.00086904 -0.00698214  0.00854727]... (showing first 5 dimensions)
#
# Top 5 similar words to 'laboratories':
# conversations: 0.2608
# reports: 0.2365
# someone: 0.2287
# language: 0.2146
# name: 0.1911
#
# --------------------------------------------------
#
# Vector for 'speak': [-0.00676279 -0.00850759  0.00861839 -0.00056135 -0.00036293]... (showing first 5 dimensions)
#
# Top 5 similar words to 'speak':
# questions: 0.2666
# works: 0.2372
# booking: 0.2000
# reports: 0.1834
# i: 0.1796
#
# --------------------------------------------------
#
# Vector for 'kind': [ 0.00878124 -0.00217884  0.00440393 -0.00097241  0.00377203]... (showing first 5 dimensions)
#
# Top 5 similar words to 'kind':
# hope: 0.3161
# 289-548-9280: 0.2889
# sentences: 0.2702
# name: 0.2046
# yes: 0.2005
#
# --------------------------------------------------
#
# Vector for 'captions': [-0.00838919  0.00809799  0.0064364   0.00133857 -0.00268609]... (showing first 5 dimensions)
#
# Top 5 similar words to 'captions':
# which: 0.2498
# when: 0.2198
# &: 0.2076
# communication: 0.1977
# me: 0.1919
#
# --------------------------------------------------
#
# Vector for 'language': [-0.0056639   0.00391347  0.00131359 -0.00851801 -0.00507208]... (showing first 5 dimensions)
#
# Top 5 similar words to 'language':
# blood: 0.3136
# laboratories: 0.2146
# number: 0.2126
# us: 0.2076
# patients: 0.1858
#
# --------------------------------------------------
#
# Vector for 'en': [ 0.00909642  0.00902048 -0.00614671  0.00110588 -0.0087013 ]... (showing first 5 dimensions)
#
# Top 5 similar words to 'en':
# been: 0.2576
# check: 0.2466
# i: 0.2424
# front: 0.2407
# reports: 0.2179
#
# --------------------------------------------------
#
# Vector for 'back': [-0.00173527  0.00228856 -0.00369521  0.0089603  -0.00473234]... (showing first 5 dimensions)
#
# Top 5 similar words to 'back':
# friday: 0.2893
# very: 0.2340
# card: 0.2167
# job: 0.2147
# bye: 0.2050
#
# --------------------------------------------------
#
# Vector for 'conversation': [ 0.0073241   0.0004622   0.00243169 -0.00598678 -0.00404672]... (showing first 5 dimensions)
#
# Top 5 similar words to 'conversation':
# toronto: 0.3076
# lesson: 0.2559
# after: 0.2424
# morning: 0.2417
# over: 0.2046
#
# --------------------------------------------------
#
# Vector for 'receptionists': [-0.0091624  -0.00807782 -0.0093428   0.00185773  0.00207034]... (showing first 5 dimensions)
#
# Top 5 similar words to 'receptionists':
# 9: 0.2613
# canceled: 0.2496
# should: 0.2271
# listen: 0.2120
# such: 0.2119
#
# --------------------------------------------------
#
# Vector for 'learn': [-0.00669448 -0.00143767  0.00646969 -0.0039835  -0.00110471]... (showing first 5 dimensions)
#
# Top 5 similar words to 'learn':
# hold: 0.3163
# book: 0.2717
# am: 0.2284
# with: 0.2223
# see: 0.2076
#
# --------------------------------------------------
#
# Vector for 'commonly': [-0.0025364  -0.00832314  0.00044132 -0.00396394 -0.00341878]... (showing first 5 dimensions)
#
# Top 5 similar words to 'commonly':
# today: 0.3294
# answering: 0.2501
# job: 0.2483
# monday: 0.2220
# we: 0.2212
#
# --------------------------------------------------
#
# Vector for 'used': [ 0.00523307 -0.00885908  0.00712385 -0.0012216   0.00711921]... (showing first 5 dimensions)
#
# Top 5 similar words to 'used':
# good: 0.1966
# we: 0.1857
# of: 0.1812
# it: 0.1716
# will: 0.1680
#
# --------------------------------------------------
#
# Vector for 'sentences': [ 0.00819539  0.00581081 -0.00419181  0.00907041  0.00771463]... (showing first 5 dimensions)
#
# Top 5 similar words to 'sentences':
# kind: 0.2702
# 289-548-9280: 0.2529
# pm: 0.2312
# day: 0.2039
# report: 0.2015
#
# --------------------------------------------------
#
# Vector for 'skills': [ 0.00092457 -0.00290902 -0.00346958 -0.00660911  0.00596641]... (showing first 5 dimensions)
#
# Top 5 similar words to 'skills':
# 3: 0.2888
# such: 0.2585
# new: 0.2235
# first: 0.2227
# setting: 0.2056
#
# --------------------------------------------------
#
# Vector for 'begin': [-0.00302219 -0.00865338 -0.00080133 -0.00134035  0.00389877]... (showing first 5 dimensions)
#
# Top 5 similar words to 'begin':
# call: 0.2489
# handles: 0.2285
# 145: 0.2169
# common: 0.2160
# which: 0.2108
#
# --------------------------------------------------
#
# Vector for 'doctors': [-0.0048741   0.00278699 -0.00097052 -0.00657998 -0.00418115]... (showing first 5 dimensions)
#
# Top 5 similar words to 'doctors':
# on: 0.3525
# conversations: 0.2965
# greeting: 0.2465
# new: 0.2390
# 1: 0.2384
#
# --------------------------------------------------
#
# Vector for 'inquiries': [-0.00964707 -0.00063089  0.00687106 -0.00893463  0.00592481]... (showing first 5 dimensions)
#
# Top 5 similar words to 'inquiries':
# a: 0.2586
# !: 0.2405
# minute: 0.2343
# wednesday: 0.2337
# hi: 0.2321
#
# --------------------------------------------------
#
# Vector for 'handles': [-0.00705656 -0.00553099  0.00974458 -0.00644413  0.00640456]... (showing first 5 dimensions)
#
# Top 5 similar words to 'handles':
# then: 0.3094
# between: 0.2859
# common: 0.2685
# pm: 0.2566
# call: 0.2456
#
# --------------------------------------------------
#
# Vector for 'front': [-0.00852669 -0.00203681  0.00489459  0.00446563 -0.00592669]... (showing first 5 dimensions)
#
# Top 5 similar words to 'front':
# prescription: 0.2639
# en: 0.2407
# three: 0.2282
# come: 0.1907
# listen: 0.1906
#
# --------------------------------------------------
#
# Vector for 'desk': [-0.00297085  0.00207694 -0.00719673  0.00199919  0.00723676]... (showing first 5 dimensions)
#
# Top 5 similar words to 'desk':
# vocabulary: 0.2858
# now: 0.2780
# it: 0.2442
# braxton: 0.2185
# is: 0.2149
#
# --------------------------------------------------
#
# Vector for 'nurse': [ 0.00193331 -0.00044452  0.00751797  0.00034909 -0.00259507]... (showing first 5 dimensions)
#
# Top 5 similar words to 'nurse':
# yes: 0.2797
# wonderful: 0.2658
# booking: 0.2117
# i: 0.2041
# check: 0.2033
#
# --------------------------------------------------
#
# Vector for 'report': [ 0.00144929 -0.00149172 -0.00284043  0.00324429 -0.0022814 ]... (showing first 5 dimensions)
#
# Top 5 similar words to 'report':
# a.m: 0.3315
# that: 0.2546
# sarah: 0.2430
# okay: 0.2344
# yes: 0.2316
#
# --------------------------------------------------
#
# Vector for 'pharmacy': [ 0.00299087 -0.00245481  0.00898397  0.00914831 -0.00478016]... (showing first 5 dimensions)
#
# Top 5 similar words to 'pharmacy':
# communication: 0.3124
# canceled: 0.2535
# duties: 0.2484
# works: 0.2294
# wonderful: 0.2250
#
# --------------------------------------------------
#
# Vector for 'medication': [-0.00998595 -0.00910271  0.00585983  0.0098499  -0.0070716 ]... (showing first 5 dimensions)
#
# Top 5 similar words to 'medication':
# messages: 0.2344
# friday: 0.1745
# wonderful: 0.1667
# ask: 0.1524
# as: 0.1425
#
# --------------------------------------------------
#
# Vector for 'prescription': [-0.00147351 -0.00555746  0.00360227  0.00054234  0.00884107]... (showing first 5 dimensions)
#
# Top 5 similar words to 'prescription':
# front: 0.2639
# .: 0.2255
# is: 0.2148
# yes: 0.2021
# patients: 0.2011
#
# --------------------------------------------------
#
# Vector for 'remember': [ 7.9149762e-03 -6.8727881e-03  9.6864598e-05 -1.2449584e-03
#  -3.8163683e-03]... (showing first 5 dimensions)
#
# Top 5 similar words to 'remember':
# dr: 0.3115
# dr.: 0.2468
# in: 0.2427
# about: 0.2322
# see: 0.2235
#
# --------------------------------------------------
#
# Vector for 'very': [ 0.0020831   0.00194437 -0.00921432  0.00484165 -0.00106425]... (showing first 5 dimensions)
#
# Top 5 similar words to 'very':
# no: 0.3002
# last: 0.2374
# braxton: 0.2357
# back: 0.2340
# taking: 0.2084
#
# --------------------------------------------------
#
# Vector for 'communicates': [-0.00613518  0.00826058 -0.00645792  0.00809691 -0.0094814 ]... (showing first 5 dimensions)
#
# Top 5 similar words to 'communicates':
# dr.: 0.2612
# messages: 0.2271
# duties: 0.2199
# questions: 0.2109
# for: 0.1980
#
# --------------------------------------------------
#
# Vector for 'messages': [-0.00761185 -0.00747699  0.00373033  0.00811744 -0.00793076]... (showing first 5 dimensions)
#
# Top 5 similar words to 'messages':
# 3: 0.2786
# cancelling: 0.2503
# know: 0.2442
# inquire: 0.2411
# 145: 0.2395
#
# --------------------------------------------------
#
# Vector for 'asking': [-0.00400896  0.008175   -0.00811752  0.00701218 -0.00022365]... (showing first 5 dimensions)
#
# Top 5 similar words to 'asking':
# health: 0.2773
# an: 0.2390
# bye: 0.2290
# you: 0.2274
# about: 0.2215
#
# --------------------------------------------------
#
# Vector for 'managing': [-0.00671208  0.00236982 -0.00040845  0.00214053 -0.00612114]... (showing first 5 dimensions)
#
# Top 5 similar words to 'managing':
# an: 0.2330
# yonge: 0.2201
# polite: 0.2074
# contact: 0.2052
# would: 0.2017
#
# --------------------------------------------------
#
# Vector for 'sure': [-0.00703873 -0.00134852 -0.00858336 -0.00072758 -0.00240402]... (showing first 5 dimensions)
#
# Top 5 similar words to 'sure':
# conversations: 0.2432
# include: 0.2339
# call: 0.2188
# 219: 0.2011
# back: 0.1993
#
# --------------------------------------------------
#
# Vector for 'still': [0.00348731 0.00776161 0.00591622 0.0084652  0.00641463]... (showing first 5 dimensions)
#
# Top 5 similar words to 'still':
# which: 0.2373
# letting: 0.2273
# person: 0.2263
# long: 0.1991
# include: 0.1975
#
# --------------------------------------------------
#
# Vector for 'check': [-0.00151308  0.00463025  0.00167075  0.00609327  0.00055774]... (showing first 5 dimensions)
#
# Top 5 similar words to 'check':
# 9: 0.2551
# en: 0.2466
# possible: 0.2268
# see: 0.2201
# doctors: 0.2060
#
# --------------------------------------------------
#
# Vector for 'know': [-0.00717223 -0.00924025 -0.003871    0.00942552 -0.00382738]... (showing first 5 dimensions)
#
# Top 5 similar words to 'know':
# patient: 0.2490
# messages: 0.2442
# my: 0.2439
# waiting: 0.2199
# 238-2838: 0.2160
#
# --------------------------------------------------
#
# Vector for 'us': [0.00784131 0.00985581 0.00035351 0.00146633 0.0032242 ]... (showing first 5 dimensions)
#
# Top 5 similar words to 'us':
# on: 0.3347
# last: 0.2618
# next: 0.2486
# me: 0.2458
# 're: 0.2430
#
# --------------------------------------------------
#
# Vector for 'letting': [ 0.00464252  0.00593262 -0.00203906 -0.00130801 -0.00560676]... (showing first 5 dimensions)
#
# Top 5 similar words to 'letting':
# ask: 0.3224
# a: 0.2278
# booking: 0.2276
# still: 0.2273
# 289-548-9280: 0.2150
#
# --------------------------------------------------
#
# Vector for 'canceled': [-0.00865717 -0.0051981   0.00361179 -0.0029299  -0.0074216 ]... (showing first 5 dimensions)
#
# Top 5 similar words to 'canceled':
# pharmacy: 0.2535
# receptionists: 0.2496
# first: 0.2264
# okay: 0.2006
# like: 0.1929
#
# --------------------------------------------------
#
# Vector for 'been': [ 0.00269434 -0.00117848 -0.00833888 -0.00364735 -0.00540404]... (showing first 5 dimensions)
#
# Top 5 similar words to 'been':
# en: 0.2576
# yes: 0.2482
# bye: 0.2166
# next: 0.2139
# book: 0.1989
#
# --------------------------------------------------
#
# Vector for 'marceli': [ 0.00328712  0.00431405 -0.00263536  0.00615062 -0.00160741]... (showing first 5 dimensions)
#
# Top 5 similar words to 'marceli':
# 238-2838: 0.3355
# dr.: 0.2846
# a.m: 0.2142
# cancelling: 0.2026
# first: 0.1826
#
# --------------------------------------------------
#
# Vector for 'cancel': [-0.00565216 -0.00825946 -0.00909846  0.00377583 -0.00224   ]... (showing first 5 dimensions)
#
# Top 5 similar words to 'cancel':
# inquire: 0.2831
# ,: 0.2338
# liam: 0.2093
# 238-2838: 0.2029
# nurse: 0.1968
#
# --------------------------------------------------
#
# Vector for 'yonge': [-0.00542874 -0.00735917 -0.00583931 -0.00568311  0.00364664]... (showing first 5 dimensions)
#
# Top 5 similar words to 'yonge':
# with: 0.2799
# would: 0.2475
# important: 0.2464
# vocabulary: 0.2409
# book: 0.2324
#
# --------------------------------------------------
#
# Vector for 'need': [ 0.00038445  0.00399983  0.00456183 -0.0083911   0.00396485]... (showing first 5 dimensions)
#
# Top 5 similar words to 'need':
# has: 0.4193
# listen: 0.2526
# yes: 0.2182
# emma: 0.2142
# thanks: 0.2135
#
# --------------------------------------------------
#
# Vector for '00': [-0.00478415  0.00696165 -0.00708146 -0.00614168 -0.00506234]... (showing first 5 dimensions)
#
# Top 5 similar words to '00':
# the: 0.2622
# morning: 0.2279
# an: 0.2091
# say: 0.2011
# communicates: 0.1979
#
# --------------------------------------------------
#
# Vector for 'busy': [-0.00766925  0.00709668  0.00664242 -0.00309497  0.00108408]... (showing first 5 dimensions)
#
# Top 5 similar words to 'busy':
# come: 0.2173
# &: 0.2088
# set: 0.2013
# street: 0.1812
# monday: 0.1768
#
# --------------------------------------------------
#
# Vector for ''m': [-0.00674209 -0.00415003  0.00251521 -0.00595991 -0.00896005]... (showing first 5 dimensions)
#
# Top 5 similar words to ''m':
# a.m: 0.2546
# yes: 0.2262
# one: 0.2131
# inquire: 0.2054
# would: 0.1918
#
# --------------------------------------------------
#
# Vector for 'no': [-0.0016782   0.00609987 -0.00685881  0.00589374  0.00051439]... (showing first 5 dimensions)
#
# Top 5 similar words to 'no':
# very: 0.3002
# three: 0.2974
# call: 0.2508
# an: 0.2286
# what: 0.2286
#
# --------------------------------------------------
#
# Vector for 'come': [-0.00121542  0.00613595  0.00357059  0.00079416  0.00247798]... (showing first 5 dimensions)
#
# Top 5 similar words to 'come':
# busy: 0.2173
# should: 0.1996
# phone: 0.1971
# marcelli: 0.1941
# front: 0.1907
#
# --------------------------------------------------
#
# Vector for 'like': [ 0.00311893  0.0017364  -0.00258779  0.0048061  -0.00014175]... (showing first 5 dimensions)
#
# Top 5 similar words to 'like':
# again: 0.3199
# soon: 0.2479
# first: 0.2332
# 3: 0.2182
# all: 0.2116
#
# --------------------------------------------------
#
# Vector for 'just': [-0.0045108  -0.00652699  0.00554788 -0.00545659 -0.00574102]... (showing first 5 dimensions)
#
# Top 5 similar words to 'just':
# please: 0.2269
# when: 0.1983
# kind: 0.1957
# lesson: 0.1926
# conversation: 0.1900
#
# --------------------------------------------------
#
# Vector for '145': [ 0.00336487 -0.00884491 -0.0005186   0.00942511 -0.00035266]... (showing first 5 dimensions)
#
# Top 5 similar words to '145':
# patients: 0.2684
# messages: 0.2395
# thank: 0.2299
# numbers: 0.2195
# begin: 0.2169
#
# --------------------------------------------------
#
# Vector for 'street': [-0.00942953  0.00366503  0.0037344  -0.00386829  0.00265986]... (showing first 5 dimensions)
#
# Top 5 similar words to 'street':
# a: 0.2745
# at: 0.2607
# messages: 0.2304
# information: 0.1993
# which: 0.1990
#
# --------------------------------------------------
#
# Vector for 'information': [-0.00786082  0.00964093  0.00835152 -0.00875814  0.00791534]... (showing first 5 dimensions)
#
# Top 5 similar words to 'information':
# webvtt: 0.3152
# will: 0.2808
# helpful: 0.2761
# common: 0.2619
# wait: 0.2565
#
# --------------------------------------------------
#
# Vector for 'call': [-2.9032454e-03  6.3469345e-03 -2.3667874e-06 -1.8571689e-03
#   8.9324731e-03]... (showing first 5 dimensions)
#
# Top 5 similar words to 'call':
# contact: 0.3207
# common: 0.2634
# no: 0.2508
# greeting: 0.2494
# begin: 0.2489
#
# --------------------------------------------------
#
# Vector for 'job': [-0.00285953 -0.003992   -0.00666922  0.0033154  -0.00967943]... (showing first 5 dimensions)
#
# Top 5 similar words to 'job':
# ask: 0.2833
# commonly: 0.2483
# back: 0.2147
# cancel: 0.1956
# look: 0.1949
#
# --------------------------------------------------
#
# Vector for 'helpful': [-0.00745861 -0.00039514  0.00925877 -0.00190284 -0.00924087]... (showing first 5 dimensions)
#
# Top 5 similar words to 'helpful':
# common: 0.2803
# information: 0.2761
# at: 0.2426
# polite: 0.2388
# answering: 0.2184
#
# --------------------------------------------------
#
# Vector for 'lesson': [-0.0015889  -0.00121079  0.00479389  0.00728661 -0.00497114]... (showing first 5 dimensions)
#
# Top 5 similar words to 'lesson':
# conversation: 0.2559
# thanks: 0.2116
# 289-548-9280: 0.1997
# just: 0.1926
# blood: 0.1829
#
# --------------------------------------------------
#
# Vector for 'found': [-0.00863814  0.00154905 -0.00786743  0.00927221  0.00728365]... (showing first 5 dimensions)
#
# Top 5 similar words to 'found':
# works: 0.2744
# a.m: 0.2147
# as: 0.2139
# receptionists: 0.2039
# contact: 0.1974
#
# --------------------------------------------------
#
# Vector for 'hope': [ 0.0049919  -0.00404143  0.00146582  0.0020003   0.00634657]... (showing first 5 dimensions)
#
# Top 5 similar words to 'hope':
# kind: 0.3161
# when: 0.2445
# look: 0.2229
# 'll: 0.2036
# am: 0.2030
#
# --------------------------------------------------
#
# Vector for 'more': [ 0.00756276  0.01008141 -0.0082234  -0.00299796 -0.00830301]... (showing first 5 dimensions)
#
# Top 5 similar words to 'more':
# some: 0.2557
# thank: 0.2200
# on: 0.2147
# see: 0.2105
# wednesday: 0.2009
#
# --------------------------------------------------
#
# Vector for 'three': [-0.00869554 -0.0007395   0.00260016  0.0083556   0.0053291 ]... (showing first 5 dimensions)
#
# Top 5 similar words to 'three':
# contact: 0.2987
# no: 0.2974
# wanted: 0.2968
# .: 0.2879
# pharmacies: 0.2479
#
# --------------------------------------------------
#
# Vector for 'listen': [-0.00888447  0.00908727 -0.00963775  0.00238876  0.00806941]... (showing first 5 dimensions)
#
# Top 5 similar words to 'listen':
# ,: 0.3145
# use: 0.2822
# need: 0.2526
# receptionists: 0.2120
# has: 0.2039
#
# --------------------------------------------------
#
# Vector for 'seat': [-0.00533951 -0.00206413  0.00410528  0.0097364   0.00773508]... (showing first 5 dimensions)
#
# Top 5 similar words to 'seat':
# great: 0.2678
# waiting: 0.2543
# blood: 0.2376
# 289-548-9280: 0.2335
# no: 0.2211
#
# --------------------------------------------------
#
# Vector for 'toronto': [ 0.00940653 -0.00769649 -0.00077546 -0.00207404 -0.00248975]... (showing first 5 dimensions)
#
# Top 5 similar words to 'toronto':
# say: 0.3162
# conversation: 0.3076
# 2: 0.2685
# this: 0.2657
# over: 0.2618
#
# --------------------------------------------------
#
# Vector for '238-2838': [-0.00059167  0.00952468  0.00395871  0.00611283 -0.00856649]... (showing first 5 dimensions)
#
# Top 5 similar words to '238-2838':
# marceli: 0.3355
# wait: 0.2626
# know: 0.2160
# cancel: 0.2029
# no: 0.1959
#
# --------------------------------------------------
#
# Vector for ')': [-0.00305784  0.00950444  0.00983211 -0.00031084 -0.00872185]... (showing first 5 dimensions)
#
# Top 5 similar words to ')':
# reports: 0.2781
# today: 0.2726
# information: 0.2349
# .: 0.2331
# should: 0.2161
#
# --------------------------------------------------
#
# Vector for '219': [-0.00481724  0.00183697  0.00374504  0.00182092 -0.00242511]... (showing first 5 dimensions)
#
# Top 5 similar words to '219':
# long: 0.2534
# sure: 0.2011
# fine: 0.1914
# this: 0.1856
# has: 0.1844
#
# --------------------------------------------------
#
# Vector for '(': [ 0.00332391  0.00455138  0.00547806 -0.00137998 -0.007338  ]... (showing first 5 dimensions)
#
# Top 5 similar words to '(':
# possible: 0.2652
# p.m: 0.2095
# set: 0.2042
# like: 0.1921
# after: 0.1905
#
# --------------------------------------------------
#
# Vector for 'changed': [ 0.00350016 -0.00740318 -0.00077391  0.00958136  0.00423734]... (showing first 5 dimensions)
#
# Top 5 similar words to 'changed':
# !: 0.2818
# liam: 0.2605
# setting: 0.2505
# use: 0.2447
# is: 0.2435
#
# --------------------------------------------------
#
# Vector for '289-548-9280': [ 0.00774023  0.00948037  0.00680712  0.00938682 -0.0068856 ]... (showing first 5 dimensions)
#
# Top 5 similar words to '289-548-9280':
# kind: 0.2889
# sentences: 0.2529
# questions: 0.2517
# seat: 0.2335
# when: 0.2248
#
# --------------------------------------------------
#
# Vector for 'contact': [-0.00646883  0.00083338 -0.00800115  0.00754905 -0.00962761]... (showing first 5 dimensions)
#
# Top 5 similar words to 'contact':
# call: 0.3207
# three: 0.2987
# doctor: 0.2593
# ;: 0.2549
# the: 0.2422
#
# --------------------------------------------------
#
# Vector for 'yes': [-0.00302275 -0.00039205 -0.00020241 -0.00679149  0.00771759]... (showing first 5 dimensions)
#
# Top 5 similar words to 'yes':
# nurse: 0.2797
# include: 0.2572
# good: 0.2526
# name: 0.2488
# been: 0.2482
#
# --------------------------------------------------
#
# Vector for 'braxton': [ 0.00604642 -0.00296827 -0.00957093 -0.00227154  0.00442121]... (showing first 5 dimensions)
#
# Top 5 similar words to 'braxton':
# are: 0.2605
# important: 0.2599
# very: 0.2357
# desk: 0.2185
# &: 0.2087
#
# --------------------------------------------------
#
# Vector for 'emma': [ 0.00059578 -0.00012356 -0.00696147  0.0069888  -0.0010415 ]... (showing first 5 dimensions)
#
# Top 5 similar words to 'emma':
# which: 0.2419
# need: 0.2142
# yes: 0.2031
# captions: 0.1915
# nbsp: 0.1906
#
# --------------------------------------------------
#
# Vector for 'about': [-0.00920283 -0.00924039 -0.00247647  0.00122578  0.00170906]... (showing first 5 dimensions)
#
# Top 5 similar words to 'about':
# edgar: 0.2666
# ;: 0.2340
# remember: 0.2322
# conversations: 0.2272
# booking: 0.2265
#
# --------------------------------------------------
#
# Vector for 'of': [-0.00689293 -0.00680966 -0.0092456   0.00296784  0.00159633]... (showing first 5 dimensions)
#
# Top 5 similar words to 'of':
# morning: 0.2977
# help: 0.2876
# after: 0.2040
# appointment: 0.1871
# patients: 0.1826
#
# --------------------------------------------------
#
# Vector for 'minute': [ 0.00482468  0.00217557 -0.00511851 -0.00900967 -0.00634454]... (showing first 5 dimensions)
#
# Top 5 similar words to 'minute':
# first: 0.2491
# inquiries: 0.2343
# a: 0.2133
# vocabulary: 0.2131
# been: 0.1970
#
# --------------------------------------------------
#
# Vector for ''ll': [ 0.00767726 -0.00367461  0.00732472  0.00703223  0.0036256 ]... (showing first 5 dimensions)
#
# Top 5 similar words to ''ll':
# all: 0.2894
# now: 0.2145
# thank: 0.2128
# hope: 0.2036
# repeat: 0.1997
#
# --------------------------------------------------
#
# Vector for 'me': [-0.00598439  0.0026362   0.00647373 -0.00656546  0.00082695]... (showing first 5 dimensions)
#
# Top 5 similar words to 'me':
# us: 0.2458
# hold: 0.2347
# time: 0.2176
# blood: 0.2079
# look: 0.2069
#
# --------------------------------------------------
#
# Vector for 'after': [ 0.0081843  -0.00349084 -0.00239065 -0.00064323  0.00016931]... (showing first 5 dimensions)
#
# Top 5 similar words to 'after':
# reports: 0.2794
# conversation: 0.2424
# help: 0.2355
# set: 0.2197
# be: 0.2099
#
# --------------------------------------------------
#
# Vector for 'repeat': [ 0.0055505  -0.00026252 -0.00831751  0.00247248  0.0026586 ]... (showing first 5 dimensions)
#
# Top 5 similar words to 'repeat':
# wednesday: 0.2677
# wanted: 0.2402
# great: 0.2332
# 'll: 0.1997
# bye-bye: 0.1937
#
# --------------------------------------------------
#
# Vector for 'if': [0.00751744 0.00471385 0.00044229 0.0041147  0.00872304]... (showing first 5 dimensions)
#
# Top 5 similar words to 'if':
# name: 0.3964
# webvtt: 0.2630
# 289-548-9280: 0.2028
# like: 0.1961
# good: 0.1951
#
# --------------------------------------------------
#
# Vector for 'wait': [-0.00571375  0.00152248 -0.0016396  -0.00939259 -0.00225382]... (showing first 5 dimensions)
#
# Top 5 similar words to 'wait':
# have: 0.3586
# time: 0.2888
# 238-2838: 0.2626
# information: 0.2565
# now: 0.2531
#
# --------------------------------------------------
#
# Vector for 'setting': [-0.00939198 -0.00940317  0.00896189  0.00825649  0.00454917]... (showing first 5 dimensions)
#
# Top 5 similar words to 'setting':
# person: 0.3692
# someone: 0.2728
# inquire: 0.2598
# changed: 0.2505
# let: 0.2336
#
# --------------------------------------------------
#
# Vector for 'ways': [0.00743067 0.00101914 0.00757915 0.00478266 0.00178889]... (showing first 5 dimensions)
#
# Top 5 similar words to 'ways':
# ;: 0.2920
# let: 0.2684
# we: 0.2553
# questions: 0.2399
# nbsp: 0.2293
#
# --------------------------------------------------
#
# Vector for 'inquire': [-0.00711221 -0.00530032  0.00061891  0.0003496  -0.00385821]... (showing first 5 dimensions)
#
# Top 5 similar words to 'inquire':
# cancel: 0.2831
# day: 0.2610
# setting: 0.2598
# messages: 0.2411
# between: 0.2152
#
# --------------------------------------------------
#
# Vector for 'polite': [-0.00349376  0.00199926  0.00787144  0.00243784  0.0014092 ]... (showing first 5 dimensions)
#
# Top 5 similar words to 'polite':
# helpful: 0.2388
# hi: 0.2109
# managing: 0.2074
# answering: 0.2062
# questions: 0.1952
#
# --------------------------------------------------
#
# Vector for 'again': [-0.00062318 -0.00934501  0.0065203  -0.00385024 -0.00826196]... (showing first 5 dimensions)
#
# Top 5 similar words to 'again':
# like: 0.3199
# let: 0.3173
# cancelling: 0.2460
# some: 0.2416
# as: 0.2325
#
# --------------------------------------------------
#
# Vector for 'use': [ 0.00157479 -0.00583018 -0.0060103   0.00846571 -0.00031774]... (showing first 5 dimensions)
#
# Top 5 similar words to 'use':
# listen: 0.2822
# changed: 0.2447
# today: 0.2123
# lesson: 0.1812
# 2: 0.1777
#
# --------------------------------------------------
#
# Vector for 'greeting': [-0.00147279 -0.0053426   0.00682175 -0.0058501   0.00817849]... (showing first 5 dimensions)
#
# Top 5 similar words to 'greeting':
# call: 0.2494
# doctors: 0.2465
# three: 0.2451
# speaking: 0.2439
# conversations: 0.2322
#
# --------------------------------------------------
#
# Vector for 'long': [-0.00196452  0.00247041  0.00165766  0.00022011  0.00199002]... (showing first 5 dimensions)
#
# Top 5 similar words to 'long':
# communication: 0.2941
# one: 0.2595
# 219: 0.2534
# calls: 0.2492
# edgar: 0.2146
#
# --------------------------------------------------
#
# Vector for 'when': [-0.00691118  0.00302317 -0.00380826 -0.00131613 -0.00781406]... (showing first 5 dimensions)
#
# Top 5 similar words to 'when':
# a: 0.2994
# hope: 0.2445
# 289-548-9280: 0.2248
# captions: 0.2198
# 9: 0.2097
#
# --------------------------------------------------
#
# Vector for 'numbers': [ 0.00987178  0.00037957 -0.00304439 -0.00201049 -0.00043592]... (showing first 5 dimensions)
#
# Top 5 similar words to 'numbers':
# what: 0.2713
# taking: 0.2701
# wonderful: 0.2644
# waiting: 0.2390
# 145: 0.2195
#
# --------------------------------------------------
#
# Vector for 'such': [-0.00118027  0.00116177  0.00857552  0.00375119  0.00159564]... (showing first 5 dimensions)
#
# Top 5 similar words to 'such':
# .: 0.2826
# important: 0.2610
# skills: 0.2585
# over: 0.2248
# works: 0.2142
#
# --------------------------------------------------
#
# Vector for 'then': [ 0.00408291  0.00199016 -0.00589914 -0.00269788 -0.00427045]... (showing first 5 dimensions)
#
# Top 5 similar words to 'then':
# 's: 0.3246
# handles: 0.3094
# hello: 0.3078
# would: 0.2584
# appointment: 0.2068
#
# --------------------------------------------------
#
# Vector for 'should': [-0.0030325   0.00383198  0.0038808   0.00240485  0.00757806]... (showing first 5 dimensions)
#
# Top 5 similar words to 'should':
# receptionists: 0.2271
# setting: 0.2233
# ): 0.2161
# your: 0.2129
# come: 0.1996
#
# --------------------------------------------------
#
# Vector for 'common': [-0.00841785  0.00325063 -0.00363813 -0.00703354 -0.00462037]... (showing first 5 dimensions)
#
# Top 5 similar words to 'common':
# speaking: 0.2863
# rescheduling: 0.2836
# helpful: 0.2803
# handles: 0.2685
# call: 0.2634
#
# --------------------------------------------------
#
# Vector for 'questions': [-0.00349365 -0.00636589  0.00468798  0.00369769  0.00128804]... (showing first 5 dimensions)
#
# Top 5 similar words to 'questions':
# answering: 0.3064
# speak: 0.2666
# 289-548-9280: 0.2517
# booking: 0.2409
# ways: 0.2399
#
# --------------------------------------------------
#
# Vector for '2': [-0.00414639 -0.00826036  0.00888454 -0.00510776 -0.00603128]... (showing first 5 dimensions)
#
# Top 5 similar words to '2':
# toronto: 0.2685
# please: 0.2239
# again: 0.2154
# wanted: 0.1900
# how: 0.1861
#
# --------------------------------------------------
#
# Vector for 'bye-bye': [-0.0028229  -0.00298865  0.00759105  0.00183472  0.00911858]... (showing first 5 dimensions)
#
# Top 5 similar words to 'bye-bye':
# help: 0.2471
# edgar: 0.2436
# answering: 0.2221
# questions: 0.2187
# address: 0.1951
#
# --------------------------------------------------
#
# Vector for 'a.m': [-0.00612505  0.00336956 -0.00840528 -0.00253723 -0.00786444]... (showing first 5 dimensions)
#
# Top 5 similar words to 'a.m':
# report: 0.3315
# 'm: 0.2546
# contact: 0.2195
# found: 0.2147
# marceli: 0.2142
#
# --------------------------------------------------
#
# Vector for 'marcelli': [-0.00286747 -0.00583051  0.00645902  0.00112867 -0.00280852]... (showing first 5 dimensions)
#
# Top 5 similar words to 'marcelli':
# today: 0.2213
# come: 0.1941
# how: 0.1861
# book: 0.1781
# answering: 0.1777
#
# --------------------------------------------------
#
# Vector for 'possible': [0.0095847  0.00881154 0.0079273  0.00243039 0.00608848]... (showing first 5 dimensions)
#
# Top 5 similar words to 'possible':
# (: 0.2652
# let: 0.2494
# 're: 0.2332
# which: 0.2276
# check: 0.2268
#
# --------------------------------------------------
#
# Vector for 'book': [ 4.6511836e-05  3.4977293e-03 -8.3565004e-03 -6.7543439e-03
#  -4.0197317e-03]... (showing first 5 dimensions)
#
# Top 5 similar words to 'book':
# learn: 0.2717
# yonge: 0.2324
# help: 0.2285
# wait: 0.2016
# been: 0.1989
#
# --------------------------------------------------
#
# Vector for 'sarah': [-0.00308471 -0.00814148  0.00920676 -0.00111119  0.00733581]... (showing first 5 dimensions)
#
# Top 5 similar words to 'sarah':
# report: 0.2430
# greeting: 0.2295
# pharmacies: 0.2036
# appointment: 0.1942
# a.m: 0.1898
#
# --------------------------------------------------
#
# Vector for '1': [-0.00854126 -0.00646447 -0.00529971  0.0078546  -0.00163727]... (showing first 5 dimensions)
#
# Top 5 similar words to '1':
# wanted: 0.2647
# someone: 0.2597
# doctors: 0.2384
# !: 0.2286
# let: 0.2198
#
# --------------------------------------------------
#
# Vector for 'between': [-0.0079344  -0.00824468 -0.0038867   0.00765957  0.00742517]... (showing first 5 dimensions)
#
# Top 5 similar words to 'between':
# all: 0.2924
# handles: 0.2859
# see: 0.2478
# good: 0.2242
# inquire: 0.2152
#
# --------------------------------------------------
#
# Vector for 'set': [-0.00470471 -0.00121826  0.00779454  0.00511594 -0.00637524]... (showing first 5 dimensions)
#
# Top 5 similar words to 'set':
# say: 0.2286
# after: 0.2197
# (: 0.2042
# busy: 0.2013
# p.m: 0.1883
#
# --------------------------------------------------
#
# Vector for 'pm': [ 0.00607952 -0.00057585  0.00229579 -0.0076835   0.0057423 ]... (showing first 5 dimensions)
#
# Top 5 similar words to 'pm':
# handles: 0.2566
# works: 0.2488
# sentences: 0.2312
# ways: 0.2187
# you: 0.2169
#
# --------------------------------------------------
#
# Vector for 'p.m': [ 0.00201945 -0.0018947  -0.00709168  0.00704693 -0.00846053]... (showing first 5 dimensions)
#
# Top 5 similar words to 'p.m':
# say: 0.3160
# today: 0.2907
# ;: 0.2473
# new: 0.2313
# possible: 0.2249
#
# --------------------------------------------------
#
# Vector for 'afternoon': [ 0.00260822 -0.0025409  -0.00913477  0.00561704 -0.00247729]... (showing first 5 dimensions)
#
# Top 5 similar words to 'afternoon':
# are: 0.2205
# in: 0.2097
# remember: 0.2020
# can: 0.2007
# an: 0.1951
#
# --------------------------------------------------
#
# Vector for 'which': [-0.0004014   0.00750204 -0.00235449  0.00427534 -0.00228372]... (showing first 5 dimensions)
#
# Top 5 similar words to 'which':
# nbsp: 0.2509
# captions: 0.2498
# emma: 0.2419
# a: 0.2402
# still: 0.2373
#
# --------------------------------------------------
#
# Vector for 'last': [ 0.00936636 -0.0047635   0.00959966  0.00880025  0.00706353]... (showing first 5 dimensions)
#
# Top 5 similar words to 'last':
# us: 0.2618
# very: 0.2374
# a: 0.2247
# pharmacies: 0.1905
# changed: 0.1820
#
# --------------------------------------------------
#
# Vector for 'first': [ 0.00033375  0.00295162 -0.00757631 -0.00576313  0.00150035]... (showing first 5 dimensions)
#
# Top 5 similar words to 'first':
# minute: 0.2491
# like: 0.2332
# appointments: 0.2297
# canceled: 0.2264
# skills: 0.2227
#
# --------------------------------------------------
#
# Vector for 'ask': [0.00345778 0.00122075 0.00305918 0.00460823 0.00890564]... (showing first 5 dimensions)
#
# Top 5 similar words to 'ask':
# letting: 0.3224
# job: 0.2833
# commonly: 0.2189
# good: 0.2085
# nbsp: 0.1904
#
# --------------------------------------------------
#
# Vector for 'webvtt': [ 0.00444806  0.00262331  0.00992521  0.00394943 -0.006526  ]... (showing first 5 dimensions)
#
# Top 5 similar words to 'webvtt':
# information: 0.3152
# if: 0.2630
# patients: 0.2442
# the: 0.2002
# or: 0.1911
#
# --------------------------------------------------
